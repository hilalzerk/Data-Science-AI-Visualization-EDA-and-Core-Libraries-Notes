# %% [markdown]
# # 1.Temel / Standart Kütüphaneler
# (Python ile birlikte otomatik gelir, ayrıca kurulum gerekmez)
# - os – işletim sistemi işlemleri
# - sys – Python çalışma ortamı ile ilgili işlemler
# - math – matematiksel fonksiyonlar
# - random – rastgele sayı üretimi
# - datetime – tarih ve zaman işlemleri
# - time – zaman ölçümü
# - re – düzenli ifadeler (regex)
# - json – JSON okuma/yazma
# - csv – CSV dosyalarıyla çalışma
# - collections – gelişmiş veri yapıları
# - itertools – döngü ve kombinasyon araçları
# - pathlib – dosya/dizin yolları
# - logging – loglama
# - statistics – temel istatistik fonksiyonları

# %% [markdown]
# # 2.Veri Analizi ve Veri Bilimi Kütüphaneleri
# ## Temel Veri İşleme
# - NumPy – sayısal hesaplama, diziler (array)
# - Pandas – tablo veri yapıları, veri temizleme ve analiz
# - SciPy – bilimsel hesaplama
# - Statsmodels – istatistiksel modelleme
# ## Veri Görselleştirme
# - Matplotlib – temel grafikler
# - Seaborn – istatistiksel ve estetik grafikler
# - Plotly – etkileşimli grafikler
# - Altair – deklaratif grafikler

# %% [markdown]
# # 3.Makine Öğrenmesi ve Yapay Zekâ
# ## Klasik Makine Öğrenmesi
# - Scikit-learn – sınıflandırma, regresyon, kümeleme
# - XGBoost
# - LightGBM
# - CatBoost
# ## Derin Öğrenme
# - TensorFlow
# - Keras
# - PyTorch
# - FastAI

# %% [markdown]
# # 4.Doğal Dil İşleme (NLP)
# - NLTK
# - spaCy
# - Gensim
# - Transformers (Hugging Face)
# - TextBlob

# %% [markdown]
# # 5.Görüntü İşleme
# OpenCV,
# Pillow (PIL),
# scikit-image,

# %% [markdown]
# # 6.Web Geliştirme
# ## Backend
# Flask,
# Django,
# FastAPI,
# Bottle,
# ## API / HTTP
# Requests,
# httpx,

# %% [markdown]
# # 7.Veri Toplama & Web Scraping
# - BeautifulSoup
# - Scrapy
# - Selenium

# %% [markdown]
# # 8.Büyük Veri & Dağıtık Sistemler
# PySpark,
# Dask,
# Ray,

# %% [markdown]
# # 9.Veri Tabanı & ORM
# SQLAlchemy,
# psycopg2 (PostgreSQL),
# sqlite3,
# pymysql,
# mongoengine / pymongo,

# %% [markdown]
# # 10.Otomasyon & Yardımcı Araçlar
# - tqdm – progress bar
# - schedule – zamanlama
# - argparse – komut satırı argümanları
# - click – CLI uygulamaları
# - dotenv (python-dotenv) – ortam değişkenleri
# - pytest / unittest – test

# %% [markdown]
# # 11.Notebook ve Çalışma Ortamı
# - Jupyter Notebook
# - IPython
# - Notebook / JupyterLab
