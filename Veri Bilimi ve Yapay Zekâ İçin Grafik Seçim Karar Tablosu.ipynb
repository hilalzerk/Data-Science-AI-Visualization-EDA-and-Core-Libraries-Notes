# %% [markdown]
# # Grafik Seçim Karar Tablosu (Veri Bilimi & Yapay Zekâ)
#
# Bu tablo, veri analizi ve makine öğrenmesi sürecinde
# hangi problem için hangi grafiklerin tercih edilmesi gerektiğini özetler.
#
# ---
#
# ## 1. Veri Keşfi (EDA – Exploratory Data Analysis)
#
# | Problem / Amaç | Kullanılacak Grafik | Kütüphane | Neden |
# |----------------|---------------------|-----------|--------|
# | Sayısal verinin dağılımını görmek | Histogram | Matplotlib / Seaborn | Veri dağılımını ve çarpıklığı gösterir |
# | Dağılım + yoğunluk birlikte | Histogram + KDE | Seaborn | Normal dağılıma yakınlık analizi |
# | Aykırı değerleri görmek | Box Plot | Matplotlib / Seaborn | Outlier tespiti için idealdir |
# | Kategorik değişkenleri karşılaştırmak | Bar Chart | Matplotlib / Seaborn | Sınıflar arası farkı gösterir |
# | Değişkenler arası ilişki | Scatter Plot | Matplotlib / Seaborn | Korelasyon sezgisi verir |
# | Çoklu değişken ilişkisi | Pair Plot | Seaborn | Tüm değişken ilişkilerini gösterir |
# | Korelasyon analizi | Heatmap | Seaborn | Değişken ilişkilerini özetler |
#
# ---
#
# ## 2. Zaman Serisi ve Trend Analizi
#
# | Problem / Amaç | Grafik | Kütüphane | Neden |
# |----------------|--------|-----------|--------|
# | Zamanla değişimi görmek | Line Plot | Matplotlib | Trend takibi |
# | Mevsimsellik incelemek | Line Plot | Matplotlib | Periyodik yapı analizi |
# | Birden fazla seri karşılaştırmak | Çoklu Line Plot | Matplotlib | Performans kıyaslama |
# | Zaman bazlı dağılım | Area Plot | Matplotlib | Birikimli etki |
#
# ---
#
# ## 3. Veri Temizleme ve Ön İşleme Kontrolü
#
# | Problem | Grafik | Kütüphane | Amaç |
# |--------|--------|-----------|------|
# | Aykırı değer kontrolü | Box Plot | Seaborn | Hatalı ölçümleri bulmak |
# | Veri dağılımını gözden geçirmek | Histogram | Matplotlib | Normalizasyon öncesi |
# | Feature ölçekleme etkisi | Histogram | Matplotlib | Ölçekleme sonrası kontrol |
# | Eksik veri dağılımı | Heatmap | Seaborn | Missing value analizi |
#
# ---
#
# ## 4. Makine Öğrenmesi – Model Kurmadan Önce
#
# | Amaç | Grafik | Kütüphane | Açıklama |
# |------|--------|-----------|----------|
# | Feature ilişkileri | Scatter Plot | Seaborn | Bağımlı–bağımsız ilişki |
# | Feature korelasyonu | Heatmap | Seaborn | Multicollinearity kontrolü |
# | Sınıf dağılımı | Bar Chart | Matplotlib | Dengesiz veri kontrolü |
# | Özellik önemini sezgisel görmek | Bar Chart | Matplotlib | Feature importance öncesi |
#
# ---
#
# ## 5. Model Sonrası Değerlendirme
#
# | Problem | Grafik | Kütüphane | Amaç |
# |--------|--------|-----------|------|
# | Gerçek vs tahmin | Scatter Plot | Matplotlib | Model doğruluğunu görsel kontrol |
# | Hata analizi | Residual Plot | Matplotlib | Bias / varyans analizi |
# | Sınıflandırma başarımı | Confusion Matrix Heatmap | Seaborn | Yanlış / doğru sınıflar |
# | Olasılık performansı | ROC Curve | Matplotlib | Model karşılaştırma |
# | Precision–Recall | PR Curve | Matplotlib | Dengesiz veri için analiz |
#
# ---
#
# ## 6. Sunum ve Dashboard Amaçlı Grafikler
#
# | Amaç | Grafik | Kütüphane | Neden |
# |------|--------|-----------|--------|
# | Etkileşimli grafik | Line / Bar | Plotly | Hover + zoom |
# | Dashboard | Çoklu grafik | Plotly | Sunum ve web uyumu |
# | Kullanıcı etkileşimi | Scatter | Plotly | İnceleme kolaylığı |
#
# ---
#
# ## 7. Hızlı Karar Rehberi (Ezberlik)
#
# - 📊 **Dağılım görmek istiyorsan → Histogram**
# - 📦 **Aykırı değer → Boxplot**
# - 🔗 **İlişki → Scatter**
# - 🔥 **Korelasyon → Heatmap**
# - 📈 **Zaman → Line**
# - 📊 **Kategori → Bar**
# - 🤖 **Model hatası → Residual plot**
# - 🎯 **Gerçek vs tahmin → Scatter**
# - 📊 **Sınıf dengesi → Bar**
# - 🌐 **Sunum → Plotly**
